# %%
import numpy as np
import pandas as pd
from astropy.table import Table
import seaborn as sns
sns.set_theme(style="ticks")

# %%
df = pd.read_csv("../smc-final-withsplus-mag-updated.csv")

# %%
df
# Out:
#         Field                        ID       RA_r      DEC_r       X_r  \
# 0   b'MC0093'  b'iDR4_3_MC0093_0155050'   7.338498 -72.235330   8596.47
# 1   b'MC0093'  b'iDR4_3_MC0093_0237121'   8.161891 -71.699936   6994.68
# 2   b'MC0093'  b'iDR4_3_MC0093_0391833'  10.340383 -72.754684   2683.99
# 3   b'MC0048'  b'iDR4_3_MC0048_0001615'  14.022394 -70.323906   9471.20
# 4   b'MC0117'  b'iDR4_3_MC0117_0000452'  21.049377 -74.042280  10240.92
# 5   b'MC0117'  b'iDR4_3_MC0117_0009311'  25.792791 -72.950714   1454.47
# 6   b'MC0094'  b'iDR4_3_MC0094_0050815'  13.296437 -72.752070   5572.11
# 7   b'MC0094'  b'iDR4_3_MC0094_0137028'  14.218616 -72.350620   3743.68
# 8   b'MC0094'  b'iDR4_3_MC0094_0174449'  14.081082 -72.116180   3997.53
# 9   b'MC0094'  b'iDR4_3_MC0094_0183910'  14.817113 -72.033320   2504.92
# 10  b'MC0094'  b'iDR4_3_MC0094_0213041'  14.918745 -71.637570   2231.52
# 11  b'MC0094'  b'iDR4_3_MC0094_0580821'  14.128065 -72.450584   3932.01
# ...

# %%
df.describe()
# Out:
#             RA_r      DEC_r           X_r           Y_r  s2n_r_psf  \
# count  58.000000  58.000000     58.000000     58.000000  58.000000
# mean   13.129343 -73.013773   5669.182759   5440.854310  39.763166
# std     3.500284   0.940586   2877.215313   2580.140286  26.408120
# min     5.887041 -75.272514   1454.470000   1068.200000   4.133588
# 25%    11.352699 -73.574624   2874.395000   3417.252500  18.689676
# 50%    12.781567 -73.009310   5164.185000   5379.620000  30.513096
# 75%    14.670355 -72.451605   8276.540000   7535.717500  62.821079
# max    25.792791 -70.323906  10339.840000  10075.870000  98.454544
#
#        s2n_J0660_psf  s2n_i_psf  CLASS_STAR_r  CLASS_STAR_i      u_psf  ...  \
# count      58.000000  58.000000     58.000000      58.00000  58.000000  ...
# mean       71.742902  60.322215      0.810345      46.62069  61.372065  ...
# std        31.665100  37.787518      0.395452      49.31027  40.678873  ...
# ...

# %%
sns.pairplot(df, hue="CLASS_STAR_r")
